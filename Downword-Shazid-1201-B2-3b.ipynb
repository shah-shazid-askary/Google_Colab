# %%
def f(x):
  return -x**2 + 4*x;

# %%
def hill_climbing(f, x0, step_size=0.1, max_iterations=100):
    x = x0  # Start with the initial solution
    steps = [(0, x, f(x))] # Store initial step (iteration, x, f(x))
    best_score = f(x) # Store the best score found so far

    for i in range(max_iterations):
        print(f"Iteration {i+1}: x = {x:.2f}, f(x) = {f(x):.2f}")

        # Generate neighbors
        neighbor_left = x - step_size
        neighbor_right = x + step_size

        # Evaluate neighbors
        f_current = f(x)
        f_left = f(neighbor_left)
        f_right = f(neighbor_right)

        # Find the best neighbor
        if f_left < f_current:
            x = neighbor_left  # Move to the left neighbor
        elif f_right < f_current:
            x = neighbor_right  # Move to the right neighbor
        else:
            break  # No better neighbor found, terminate

        steps.append((i+1, x, f(x))) # Store the step (iteration, x, f(x))
        best_score = f(x) # Update best score

    return x, steps, best_score

# Shazid ID:0242310005431201
# Run Hill Climbing
initial_solution = 3.0  # Start at x = 3.0
best_solution, steps, best_score = hill_climbing(f, initial_solution)
print(f"\nBest solution: x = {best_solution:.2f}, f(x) = {f(best_solution):.2f}")
# Out:
# Iteration 1: x = 3.00, f(x) = 3.00
# Iteration 2: x = 3.10, f(x) = 2.79
# Iteration 3: x = 3.20, f(x) = 2.56
# Iteration 4: x = 3.30, f(x) = 2.31
# Iteration 5: x = 3.40, f(x) = 2.04
# Iteration 6: x = 3.50, f(x) = 1.75
# Iteration 7: x = 3.60, f(x) = 1.44
# Iteration 8: x = 3.70, f(x) = 1.11
# Iteration 9: x = 3.80, f(x) = 0.76
# Iteration 10: x = 3.90, f(x) = 0.39
# Iteration 11: x = 4.00, f(x) = -0.00
# Iteration 12: x = 4.10, f(x) = -0.41
# Iteration 13: x = 4.20, f(x) = -0.84
# Iteration 14: x = 4.30, f(x) = -1.29
# Iteration 15: x = 4.40, f(x) = -1.76
# Iteration 16: x = 4.50, f(x) = -2.25
# Iteration 17: x = 4.60, f(x) = -2.76
# Iteration 18: x = 4.70, f(x) = -3.29
# Iteration 19: x = 4.80, f(x) = -3.84
# Iteration 20: x = 4.90, f(x) = -4.41
# Iteration 21: x = 5.00, f(x) = -5.00
# Iteration 22: x = 5.10, f(x) = -5.61
# Iteration 23: x = 5.20, f(x) = -6.24
# Iteration 24: x = 5.30, f(x) = -6.89
# Iteration 25: x = 5.40, f(x) = -7.56
# Iteration 26: x = 5.50, f(x) = -8.25
# Iteration 27: x = 5.60, f(x) = -8.96
# Iteration 28: x = 5.70, f(x) = -9.69
# Iteration 29: x = 5.80, f(x) = -10.44
# Iteration 30: x = 5.90, f(x) = -11.21
# Iteration 31: x = 6.00, f(x) = -12.00
# Iteration 32: x = 6.10, f(x) = -12.81
# Iteration 33: x = 6.20, f(x) = -13.64
# Iteration 34: x = 6.30, f(x) = -14.49
# Iteration 35: x = 6.40, f(x) = -15.36
# Iteration 36: x = 6.50, f(x) = -16.25
# Iteration 37: x = 6.60, f(x) = -17.16
# Iteration 38: x = 6.70, f(x) = -18.09
# Iteration 39: x = 6.80, f(x) = -19.04
# Iteration 40: x = 6.90, f(x) = -20.01
# Iteration 41: x = 7.00, f(x) = -21.00
# Iteration 42: x = 7.10, f(x) = -22.01
# Iteration 43: x = 7.20, f(x) = -23.04
# Iteration 44: x = 7.30, f(x) = -24.09
# Iteration 45: x = 7.40, f(x) = -25.16
# Iteration 46: x = 7.50, f(x) = -26.25
# Iteration 47: x = 7.60, f(x) = -27.36
# Iteration 48: x = 7.70, f(x) = -28.49
# Iteration 49: x = 7.80, f(x) = -29.64
# Iteration 50: x = 7.90, f(x) = -30.81
# Iteration 51: x = 8.00, f(x) = -32.00
# Iteration 52: x = 8.10, f(x) = -33.21
# Iteration 53: x = 8.20, f(x) = -34.44
# Iteration 54: x = 8.30, f(x) = -35.69
# Iteration 55: x = 8.40, f(x) = -36.96
# Iteration 56: x = 8.50, f(x) = -38.25
# Iteration 57: x = 8.60, f(x) = -39.56
# Iteration 58: x = 8.70, f(x) = -40.89
# Iteration 59: x = 8.80, f(x) = -42.24
# Iteration 60: x = 8.90, f(x) = -43.61
# Iteration 61: x = 9.00, f(x) = -45.00
# Iteration 62: x = 9.10, f(x) = -46.41
# Iteration 63: x = 9.20, f(x) = -47.84
# Iteration 64: x = 9.30, f(x) = -49.29
# Iteration 65: x = 9.40, f(x) = -50.76
# Iteration 66: x = 9.50, f(x) = -52.25
# Iteration 67: x = 9.60, f(x) = -53.76
# Iteration 68: x = 9.70, f(x) = -55.29
# Iteration 69: x = 9.80, f(x) = -56.84
# Iteration 70: x = 9.90, f(x) = -58.41
# Iteration 71: x = 10.00, f(x) = -60.00
# Iteration 72: x = 10.10, f(x) = -61.61
# Iteration 73: x = 10.20, f(x) = -63.24
# Iteration 74: x = 10.30, f(x) = -64.89
# Iteration 75: x = 10.40, f(x) = -66.56
# Iteration 76: x = 10.50, f(x) = -68.25
# Iteration 77: x = 10.60, f(x) = -69.96
# Iteration 78: x = 10.70, f(x) = -71.69
# Iteration 79: x = 10.80, f(x) = -73.44
# Iteration 80: x = 10.90, f(x) = -75.21
# Iteration 81: x = 11.00, f(x) = -77.00
# Iteration 82: x = 11.10, f(x) = -78.81
# Iteration 83: x = 11.20, f(x) = -80.64
# Iteration 84: x = 11.30, f(x) = -82.49
# Iteration 85: x = 11.40, f(x) = -84.36
# Iteration 86: x = 11.50, f(x) = -86.25
# Iteration 87: x = 11.60, f(x) = -88.16
# Iteration 88: x = 11.70, f(x) = -90.09
# Iteration 89: x = 11.80, f(x) = -92.04
# Iteration 90: x = 11.90, f(x) = -94.01
# Iteration 91: x = 12.00, f(x) = -96.00
# Iteration 92: x = 12.10, f(x) = -98.01
# Iteration 93: x = 12.20, f(x) = -100.04
# Iteration 94: x = 12.30, f(x) = -102.09
# Iteration 95: x = 12.40, f(x) = -104.16
# Iteration 96: x = 12.50, f(x) = -106.25
# Iteration 97: x = 12.60, f(x) = -108.36
# Iteration 98: x = 12.70, f(x) = -110.49
# Iteration 99: x = 12.80, f(x) = -112.64
# Iteration 100: x = 12.90, f(x) = -114.81
#
# Best solution: x = 13.00, f(x) = -117.00

# %%
import matplotlib.pyplot as plt
import numpy as np
# Generate data for plotting the objective function
x_values = np.linspace(-5, 5, 400) # Adjust range for better visualization
y_values = f(x_values)

# Plot the objective function
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Objective Function')

# Extract x and y values from the steps
step_x = [step[1] for step in steps]
step_y = [step[2] for step in steps]
# Shazid ID:0242310005431201
# Plot the steps taken by the algorithm
plt.scatter(step_x, step_y, color='red', label='Hill Climbing Steps')
plt.plot(step_x, step_y, color='red', linestyle='--', alpha=0.5) # Connect the steps

# Mark the starting and ending points
plt.scatter(steps[0][1], steps[0][2], color='green', marker='o', s=100, label='Start')
plt.scatter(best_solution, best_score, color='purple', marker='*', s=200, label='Best Solution Found')

plt.title('Hill Climbing Optimization Process')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
